# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 7: Supervised learning

# %% [markdown]
# ## Lab work 7

# %% [markdown]
# #### Мета:
#
# * навчитися використовувати моделі з учителем

# %% [markdown]
# ### Завдання 1:

# %% [markdown]
# Для цього завдання ми будемо вивчати загальнодоступні дані з [LendingClub.com](www.lendingclub.com).
#
# Кредитний клуб пов'язує людей, яким потрібні гроші (позичальники), та людей, які мають гроші (інвесторів). Сподіваємось, як інвестор ви хотіли б інвестувати в людей, які продемонстрували, що вони мають високу ймовірність повернути вам гроші. Ми спробуємо створити модель, яка допоможе це передбачити.

# %% [markdown]
# Кредитний клуб мав [дуже цікавий 2016 рік](https://en.wikipedia.org/wiki/Lending_Club#2016), тож давайте перевіримо деякі їх дані.
#
# Ми використовуватимемо дані про позики за 2007-2010 роки та намагатимемося класифікувати та прогнозувати, чи повертав позичальник їх повністю.

# %% [markdown]
# Ось що представляють стовпці:
# * `credit.policy`: 1, якщо клієнт відповідає критеріям андеррайтингу кредитів LendingClub.com, і 0 в іншому випадку.
#
# * `purpose`: мета позики (приймає значення "кредитна_карта", "консолідація боргу", "освітня", "основна_покупка", "малий бізнес" та "всі_інші").
#
# * `int.rate`: процентна ставка позики, пропорційно (ставка 11% зберігатиметься як 0,11). Позичальникам, які LendingClub.com вважає більш ризикованими, призначаються вищі процентні ставки.
#
# * `installment`: щомісячні виплати позичальника, якщо позика фінансується.
#
# * `log.annual.inc`: журнал річного доходу позичальника, який самостійно звітується.
#
# * `dti`: відношення боргу до доходу позичальника (сума боргу, поділена на річний дохід).
#
# * `fico`: кредитний рейтинг позичальника FICO.
#
# * `days.with.cr.line`: кількість днів, коли позичальник мав кредитну лінію.
#
# * `revol.bal`: кредитний залишок позичальника (сума не виплачена в кінці циклу виставлення рахунків за кредитною карткою).
#
# * `revol.util`: коефіцієнт використання кридитної лінії позичальника (сума використаної кредитної лінії відносно загальної кількості доступних кредитів).
#
# * `inq.last.6mths`: кількість запитів позичальників з боку кредиторів за останні 6 місяців.
#
# * `delinq.2yrs`: кількість разів, протягом яких позичальник прострочував платежі протягом останніх 2 років понад 30 днів.
#
# * `pub.rec`: кількість публічних записів (заяви про банкрутство, податкова застава або рішення).

# %% [markdown]
# Алгоритм виконання та проміжні завдання:

# %% [markdown]
# 1. Відкрийте файл та виведіть описову статистику

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# min     612.000000         178.958333  0.000000e+00     0.000000
# 25%     682.000000        2820.000000  3.187000e+03    22.600000
# 50%     707.000000        4139.958333  8.596000e+03    46.300000
# 75%     737.000000        5730.000000  1.824950e+04    70.900000
# max     827.000000       17639.958330  1.207359e+06   119.000000
#
#        inq.last.6mths  delinq.2yrs      pub.rec  not.fully.paid
# count     9578.000000  9578.000000  9578.000000     9578.000000
# mean         1.577469     0.163708     0.062122        0.160054
# std          2.200245     0.546215     0.262126        0.366676
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     0.000000     0.000000        0.000000
# 50%          1.000000     0.000000     0.000000        0.000000
# 75%          2.000000     0.000000     0.000000        0.000000
# max         33.000000    13.000000     5.000000        1.000000

# %% [markdown]
# 2. Створіть дві гістограми по полю fico (перша для значень not.fully.paid=0, друга = 1). Гістограми накладіть одна на одну.

# %%
fico_df = pd.DataFrame()
fico_df['zeros fully paid'] = df['fico'][df['not.fully.paid'] == 0].reset_index(drop=True)
fico_df['ones fully paid'] = df['fico'][df['not.fully.paid'] == 1].reset_index(drop=True)
fico_df.plot.hist(rwidth=0.95, stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# 3. Відобразіть тенденцію між оцінкою fico та int.rate. Використайте jointplot

# %%
sns.jointplot(data=df, x='fico', y='int.rate')

# %% [markdown]
# 4. Побудуйте графік lmplot на основі int.rate та fico. Коліром розідліть по полю credit.policy. Розбийте по значеннях цільової функції

# %%
sns.lmplot(x="int.rate", y="fico", data=df, hue="credit.policy")

# %% [markdown]
# 5. purpose є категорієї, тому варто перетворити за допомогою pd.get_dummies

# %%
df = pd.concat([df, pd.get_dummies(df['purpose'], prefix='purp')], axis=1)
df.sample(5)
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 5242              1  debt_consolidation    0.1357       594.45
# 5562              1  debt_consolidation    0.1357       611.44
# 9423              0  debt_consolidation    0.1114       328.04
# 9433              0           all_other    0.1322       331.25
# 4648              1  debt_consolidation    0.1114       461.71
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 5242       10.969921  13.45   692        2519.958333       5799        76.3
# 5562       10.691945   6.33   692       11101.000000       5494        14.1
# 9423       10.308953  10.52   737        2070.041667       7328        21.7
# 9433       10.463103  13.06   702        5370.000000       5088        45.4
# 4648       10.085809  13.15   752        6631.000000      13551        29.0
#
#       ...  delinq.2yrs  pub.rec  not.fully.paid  purp_all_other  \
# 5242  ...            0        0               0               0
# 5562  ...            0        0               0               0
# 9423  ...            0        0               1               0
# 9433  ...            0        0               1               1
# 4648  ...            0        0               0               0
#
#       purp_credit_card  purp_debt_consolidation  purp_educational  \
# 5242                 0                        1                 0
# 5562                 0                        1                 0
# 9423                 0                        1                 0
# 9433                 0                        0                 0
# 4648                 0                        1                 0
#
#       purp_home_improvement  purp_major_purchase  purp_small_business
# 5242                      0                    0                    0
# 5562                      0                    0                    0
# 9423                      0                    0                    0
# 9433                      0                    0                    0
# 4648                      0                    0                    0
#
# [5 rows x 21 columns]

# %% [markdown]
# 6. Розбийте датасет на тестві та трейнові дані

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, 2:] # exclude credit.policy and purpose
y = df['credit.policy']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# 7. Використайте для задачі класифікації такі моделі: дерево рішень, логістична регресія, random forest, XGBoost

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb


tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

r_forest_model = RandomForestClassifier()
r_forest_model.fit(X_train, y_train)

xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_train, y_train)
# Out:
# [23:45:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# 8. Для кожної з моделей виведіть матрицю, основні метрики

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

models_metrics = pd.DataFrame()

for model in (tree_model, lr_model, r_forest_model, xgb_model):
    model_metrics = pd.DataFrame()
    predicts = model.predict(X)
    
    model_metrics['model'] = [str(model).split('(')[0]]
    model_metrics['train score'] = [model.score(X_train, y_train)]
    model_metrics['test score'] = [model.score(X_test, y_test)]   
    model_metrics['precision score'] = [precision_score(y, predicts)] 
    model_metrics['recall score'] = [recall_score(y, predicts)] 
    model_metrics['f1 score'] = [f1_score(y, predicts)] 
    
    models_metrics = models_metrics.append(model_metrics.set_index('model'))

models_metrics
# Out:
#                         train score  test score  precision score  \
# model
# DecisionTreeClassifier     1.000000    0.989562         0.999350
# LogisticRegression         0.897118    0.892693         0.905141
# RandomForestClassifier     1.000000    0.991649         0.997928
# XGBClassifier              1.000000    0.994154         0.998833
#
#                         recall score  f1 score
# model
# DecisionTreeClassifier      0.997406  0.998377
# LogisticRegression          0.972763  0.937734
# RandomForestClassifier      0.999481  0.998704
# XGBClassifier               0.999351  0.999092

# %% [markdown]
# 8. *Використейте бібіотеку dtreeviz для візуалізації (там, де актуально)

# %% [markdown]
# Через помилку _ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH"_
# прийшлось використовувати вбудовані інструменти для побудови дерев

# %%
from sklearn import tree
from matplotlib import pyplot as plt

ax = plt.subplots(figsize=[20, 10])[0]
tree.plot_tree(tree_model)
plt.show()

# %% [markdown]
# 9. Використайте ансамбель voting для всіх моделей

# %%
from sklearn.ensemble import VotingClassifier

ereg = VotingClassifier(estimators=[('tree', tree_model), ('lr', lr_model), ('forest', r_forest_model), ('XGB', xgb_model)])
ereg.fit(X, y)

ereg.score(X, y)
# Out:
# [23:47:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1.0

# %% [markdown]
# 10. Порівняйте результати моделей та зробіть висновки

# %% [markdown]
# Висновок: Всі моделі показали хороші результати на тренованих та тестових вибірках. Це зумовлено вдалим підбором фіч та добре структурованими даними.

# %% [markdown]
# ### Завдання 2:

# %% [markdown]
# Просте завдання на обробку часових рядів.

# %% [markdown]
# Потрібно вивести наступну інформацію:

# %% [markdown]
# 1. Виведіть список унікальних міст з датасету

# %%
url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/%D0%B1%D1%8B%D1%81%D1%82%D1%80%D0%BE%D0%B5%20%D0%B2%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%B2%20pandas/data/air_quality_no2_long.csv"
df = pd.read_csv(url)

# %%
df['city'].unique()
# Out:
# array(['Paris', 'Antwerpen', 'London'], dtype=object)

# %% [markdown]
# 2. Виведіть дату початку та кінця ведення даних

# %%
df['date.utc'] = pd.to_datetime(df['date.utc'])

print('початок:', df['date.utc'].min())
print('кінець:', df['date.utc'].max())
# Out:
# початок: 2019-05-07 01:00:00+00:00
# кінець: 2019-06-21 00:00:00+00:00

# %% [markdown]
# 3. Яка середня конценрація $NO_2$ для кожного дня тижня і міста (виведіть таблицю)?

# %%
df.groupby([df['date.utc'].dt.dayofweek, 'city']).mean()
# Out:
#                         value
# date.utc city
# 0        Antwerpen  27.875000
#          London     23.969697
#          Paris      24.856250
# 1        Antwerpen  22.214286
#          London     24.885714
#          Paris      30.999359
# 2        Antwerpen  21.125000
#          London     23.460432
#          Paris      29.165753
# 3        Antwerpen  27.500000
#          London     24.780142
#          Paris      28.600690
# 4        Antwerpen  28.400000
#          London     26.446809
#          Paris      31.617986
# 5        Antwerpen  33.500000
#          London     24.977612
#          Paris      25.266154
# 6        Antwerpen  21.896552
#          London     24.859155
#          Paris      23.274306

# %% [markdown]
# 4. Яке середнє значення для кожної години (виведіть стовбчикову діаграму)?

# %%
settings = {'color' : 'tomato', 'figsize' : (12, 6)}

df.groupby(df['date.utc'].dt.hour).mean().plot.bar(**settings)
# Out:
# <AxesSubplot:xlabel='date.utc'>
