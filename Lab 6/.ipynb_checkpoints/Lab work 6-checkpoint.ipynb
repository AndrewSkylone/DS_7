# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 6: Basics of data visualization

# %% [markdown]
# ## Lab work 6

# %% [markdown]
# #### Мета:
#
# * навчитися візуалізовувати дані в Python

# %% [markdown]
# ### Завдання:

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns

# %%
np.random.seed(0)

df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30)})
df.head()
# Out:
#     a   b   c
# 0  44  47  17
# 1  47  64  79
# 2  64  82   4
# 3  67  99  42
# 4  67  88  58

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
#  - перші 3 графіки візуалізувати, викорстовуючи значення із df
#  - останній це пряма пропорційність

# %%
fig, axes = plt.subplots(2, 2, figsize=[12.5, 6], tight_layout=True)

axes[0, 0].plot(df['a'])
axes[0, 1].plot(df['b'])
axes[1, 0].plot(df['c'])
axes[1, 1].plot(np.arange(30), np.arange(30))

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку

# %%
ax = plt.subplots(figsize=[15, 9])[1]
ax.plot(df['a'], linewidth=1.2)

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`

# %%
fig, axes = plt.subplots(2, figsize=[15, 7])
axes[0].plot(df['a'])
axes[1].plot(df['b'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`
# - задайте стиль 'darkgrid' за допомогою команди `sns.set_style`

# %%
sns.set_style('darkgrid')
ax = plt.subplots(figsize=[15, 8])[1]
ax.plot(df['a'], )
ax.plot(df['b'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - для колонки `a` використайте червоний колір та лінію формату `-.`
#
# - для колонки `b` використайте помаранчевий колір та товщину `10`
#
# - для колонки `c` використайте жовтий колір та товщину `1` і маркер `o`

# %%
ax = plt.subplots(figsize=[15, 8])[1]

ax.plot(df['a'], linestyle='-.', color='red')
ax.plot(df['b'], linewidth=10, color='orange')
ax.plot(df['c'], linewidth=1, marker='o', color='yellow')

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - і не забудьте про легенду :)

# %%
axes = plt.subplots(3, figsize=(15, 8))[1]

axes[0].plot(df['a'], label='Line A')
axes[0].legend(loc='lower right')

axes[1].plot(df['b'], label='Line B')
axes[1].legend(loc='center left')

axes[2].plot(df['c'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використайте томатний колір та відстань між стовбцями 0.5

# %%
ax = plt.subplots(figsize=(15, 8))[1]

ax.bar(df.index, height=df['a'], color=['tomato'], alpha=0.5, label='a')
ax.legend()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - добавте всі підписи та правильний маркер

# %%
ax = plt.subplots(figsize=(16.7, 7))[1]

x = np.arange(df.shape[0])
ax.plot(df['a'], marker='^')

ax.set_xticks(x)
ax.set(title='This is the title', ylabel='This is the Y axis')
ax.set_xlabel('This is the X Axis', fontsize=18)
# Out:
# Text(0.5, 0, 'This is the X Axis')

# %%
# Out:
# No handles with labels found to put in legend.
