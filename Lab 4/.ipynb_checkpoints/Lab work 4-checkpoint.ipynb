# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 4: Work with data professionally!

# %% [markdown]
# ## Lab work 4

# %% [markdown]
# #### Мета:
#
# * навчитися обробляти дані
# * "парсити" сайти

# %% [markdown]
# ### Завдання 1:

# %% [markdown]
# #### Ознайомитися із API Національного банку
# https://old.bank.gov.ua/control/uk/publish/article?art_id=38441973&cat_id=38459171#exchange

# %% [markdown]
# 1. Підключитися до API.

# %%
import requests

requests.get("https://bank.gov.ua/NBUStatService/v1/statdirectory/exchange").status_code
# Out:
# 200

# %% [markdown]
# 2. Отримати курс долара за останній рік.

# %%
from datetime import date, timedelta
url = "https://bank.gov.ua/NBUStatService/v1/statdirectory/exchange?json"
year_rates = []
today = date.today()

for i in range(365):
    new_date = today - timedelta(days=i)
    r = requests.get(url, params={'valcode' : 'USD', 'date' : new_date.strftime('%Y%m%d')}).json()
    year_rates.append(r[0])

# %% [markdown]
# 3. Вивести середнє значення та відхилення курсу за кожний місяць.

# %% [markdown]
# _Cортування курсів по місяцях_

# %%
months_rates = {}

for rate in year_rates:
    month = rate['exchangedate'].split('.')[1]
    months_rates.setdefault(month, []).append(rate)

# %% [markdown]
# _Cереднє значення за кожний місяць_

# %%
avarage_months_rates = {}

for month, rates in months_rates.items():
    rates_sum = sum([rate['rate'] for rate in rates])
    avarage_months_rates[month] = rates_sum / len(rates)
    
print("середнє значення за кожний місяць: ", avarage_months_rates)
# Out:
# середнє значення за кожний місяць:  {'08': 27.202158064516134, '07': 27.214548387096773, '06': 27.239873333333335, '05': 27.60284838709677, '04': 27.930006666666664, '03': 27.79555806451613, '02': 27.88466071428572, '01': 28.21977096774193, '12': 28.169719354838726, '11': 28.310153333333332, '10': 28.324951612903224, '09': 27.976716666666665}

# %% [markdown]
# _Відхилення курсу за кожний місяц_

# %%
months_deviations = {}

for month, month_rates in months_rates.items():
    result = 0
    for rate_data in month_rates:
        result += (rate_data['rate'] - avarage_month_rates[month]) ** 2

    months_deviations[month] = (result / len(month_rates)) ** 0.5

print("відхилення курсу за кожний місяць:", months_deviations)
# Out:
# відхилення курсу за кожний місяць: {'08': 0.28087748881903335, '07': 0.1532937636737697, '06': 0.15346138696391648, '05': 0.11849255828264614, '04': 0.08930549790217603, '03': 0.113636249822287, '02': 0.10439519125243588, '01': 0.12115058663084943, '12': 0.24570683871868976, '11': 0.14835098411837006, '10': 0.054615157242512376, '09': 0.23686450850409987}

# %% [markdown]
# 4. Дану інформацію записати у файл за допомогою pickle.

# %%
import pickle

with open('rates.pickle', 'wb') as f:
    pickle.dump({'avarage month rates' : avarage_months_rates, 'months deviations' : months_deviations}, f)

# %% [markdown]
# ### Завдання 2:

# %% [markdown]
# Потрібно проаналізувати всі товари на сайті:
# https://smallpacking.agrosem.ua/shop/

# %% [markdown]
# Створіть базу даних, що містить таблицю із такими стовбцями:
#     - артикул товару
#     - найменування
#     - ціна
#     - вага

# %% [markdown]
# _Створення бази даних_

# %%
import sqlite3

shop_db = sqlite3.connect('shop.db')
curs = shop_db.cursor()
sql_req = """ 
    CREATE TABLE medications (
        sku INTEGER,
        name TEXT,
        price INTEGER
    )
 """
curs.execute(sql_req)
shop_db.commit()
shop_db.close()

# %% [markdown]
# _Заповнення бази даними_

# %%
from bs4 import BeautifulSoup
import requests


shop_db = sqlite3.connect('shop.db')
curs = shop_db.cursor()

# знаходимо к-сть сторінок
url = 'https://smallpacking.agrosem.ua/shop'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'lxml')
pages = int(soup.find_all('a', class_='page-numbers')[-2].text)

# проходимо по всіх сторінках
for page in range(1, pages + 1):
    r = requests.get(f'{url}/page/{page}/')
    soup = BeautifulSoup(r.text, 'lxml')
    products_data = soup.find_all('div', class_="product-from-category-container")
    
    # проходимо по веб елементах кожного продукта
    for data in products_data:
        sku = data.find('a', class_='button product_type_simple add_to_cart_button ajax_add_to_cart')
        sku = int(sku.get('data-product_sku'))
        name = data.find('span', class_='pruduct-name-bottom').text
        price = data.find('span', class_='regular-price').text
        price = int(price.replace('грн', '').replace(' ', ''))        

        sql_req = f""" 
            INSERT INTO medications(sku, name, price)
            VALUES ({sku}, "{name}", {price})
        """
        curs.execute(sql_req)

shop_db.commit()
shop_db.close()

# %% [markdown]
# _Відображення даних_

# %%
con = sqlite3.connect("shop.db")
cursor = con.cursor()
cursor.execute("SELECT * FROM medications")
print(*cursor.fetchall(), sep='\n')
# Out:
# (28164, 'Ferticare Hydro 6-14-30 + micro', 1900)
# (66353, 'Ferticare Kombi 14-11-25 + micro', 1700)
# (39566, 'MagPlon K (нітрат калію)', 1200)
# (69156, 'Pulan 34.4', 7500)
# (74266, 'Saletrosan®26', 4400)
# (26252, 'Saletrosan®30', 6000)
# (67325, 'Saletrzak 27 macro', 4300)
# (76913, 'Siarczan AS 21 Macro', 4700)
# (51667, 'Yara Liva Кальциніт', 550)
# (95975, 'Yara Liva Нітрабор', 550)
# (93119, 'YaraBela Сульфан', 9500)
# (35951, 'YaraIrix', 23000)
# (21521, 'YaraMila Complex 12-11-18', 850)
# (31357, 'YaraMila Cropcare 11-11-21', 850)
# (47993, 'YaraMila NP 20-20 +9,0SO3', 12600)
# (89147, 'YaraMila NPK 12-24-12', 14700)
# (84721, 'YaraMila NPK 16-16-16', 12200)
# (63243, 'YaraMila NPK 16-27-7', 15600)
# (24963, 'YaraMila NPK 18-11-13', 11300)
# (24344, 'YaraMila NPK 7-20-28', 15600)
# (64776, 'YaraMila NPK 8-24-24', 15800)
# (66872, 'YaraMila NPK 9-12-25 + 2MgO + 6,5SO3 + micro', 12800)
# (19571, 'YaraTera SOP (сульфат калію)', 1100)
# (16332, 'YaraVita Rexolin ABC (комплекс мікроелементів)', 2200)
# (77348, 'YaraVita Rexolin D12 (хелат заліза)', 2100)
# (76429, 'YaraVita Бортрак', 1500)
# (13111, 'YaraVita Брасітрел Про', 2300)
# (62796, 'YaraVita Грамітрел', 2400)
# (79615, 'YaraVita КомбіФос', 1900)
# (47133, 'YaraVita Манкоцин', 1600)
# (37314, 'YaraVita Мантрак Про', 1800)
# (22322, 'YaraVita Меїз Буст', 2700)
# (42617, 'YaraVita Молітрак', 7100)
# (94157, 'YaraVita Тепросин NP+Zn', 3200)
# (78528, 'YaraVita Тіотрак', 1300)
# (97554, 'YaraVita Фосамко Біо', 1200)
# (93579, 'YaraVita Цинтрак', 1900)
# (15119, 'Альваро КВС, насіння озимого ріпаку, 2019 р. врожаю', 5000)
# (78664, 'Альваро КВС, насіння озимого ріпаку, 2020 р. врожаю', 5700)
# (92478, 'Гибрікок KWS, 2019 р. врожаю', 4500)
# (45875, 'Гибрікок KWS, 2020 р. врожаю', 5500)
# (81892, 'Етерно КВС, насіння озимого жита', 2200)
# (91815, 'Етерно КВС, насіння озимого жита', 53000)
# (31292, 'Етерно КВС, насіння озимого жита', 50000)
# (42579, 'Етерно КВС, насіння озимого жита, протруєне', 56000)
# (68438, 'Кrista MAG (нітрат магнію)', 800)
# (66368, 'Кrista К (нітрат калію)', 1200)
# (34254, 'Кrista МАР (моноамоній фосфат)', 1500)
# (34559, 'Кrista МКР (монокалій фосфат)', 1700)
# (56714, 'КВС Боно, насіння озимого жита', 49000)
# (63683, 'КВС Магніфіко, насіння озимого жита на силос', 1900)
# (61723, 'КВС Магніфіко, насіння озимого жита на силос', 46000)
# (12789, 'КВС Пропауер, насіння озимого жита', 55000)
# (62997, 'КВС Тайо, насіння озимого жита', 55000)
# (27946, 'КВС Феррі, озимий ріпак, 2020 р. врожаю', 6000)
# (38994, 'МАРК КВС, 2019 р. врожаю', 5000)
# (99753, 'МАРК КВС, 2020 р. врожаю', 5700)
# (87931, 'Озимий ріпак Фактор КВС, 2019 р. врожаю, ексклюзив «Агросем»', 5200)
# (38134, 'Озимий ріпак Фактор КВС, 2020 р. врожаю, ексклюзив «Агросем»', 5800)
# (93768, 'ПX113, озимий ріпак', 5800)
# (32979, 'ПX128, озимий ріпак', 7000)
# (27795, 'ПР44Д06, озимий ріпак', 6400)
# (29272, 'ПР46В21, озимий ріпак', 5800)
# (67125, 'ПТ200КЛ, озимий ріпак', 7000)
# (41695, 'ПТ234, озимий ріпак', 5800)
# (84913, 'ПТ248, озимий ріпак', 6600)
# (94498, 'ПТ264, озимий ріпак', 7000)
# (45838, 'ПТ269, озимий ріпак', 6700)
# (66139, 'ПТ271, озимий ріпак', 7000)
# (87933, 'ПТ275, озимий ріпак', 7000)
# (14888, 'ПТ279КЛ, озимий ріпак', 7400)
# (87376, 'ПХ125КЛ, озимий ріпак', 7000)
# (14592, 'ПХ131, озимий ріпак', 7000)
# (65157, 'Сульфат магнію (семиводневий)', 400)
# (76265, 'Сульфат магнію гранульований', 12000)
# (75575, 'Сульфат магнію Яра Krista MgS', 500)
# (33632, 'Умберто КВС, насіння озимого ріпаку, 2019 р. врожаю', 5200)
# (88369, 'Умберто КВС, насіння озимого ріпаку, 2020 р. врожаю', 5800)
# (55781, 'Яра (Folicare) NPK 10-5-40+micro', 1800)
# (65565, 'Яра (Folicare) NPK 12-0-38', 1900)
# (88381, 'Яра (Folicare) NPK 12-46-8+micro', 2100)
# (91621, 'Яра (Folicare) NPK 18-18-18+micro', 1800)
# (68487, 'Яра (Folicare) NPK 22-5-22+micro', 1800)
# (35486, 'Яра Ferticare Tomato', 1800)
# (71533, 'Яра Ferticare Овочі', 1800)
# (439226, 'Добриво для фруктових та горіхових дерев', 375)
# (1297, 'Добриво для ягідних чагарників', 350)
# (91897, 'Добриво для ягідних чагарників', 155)
# (61169, 'Добриво універсальне грунтове', 173)
# (6651824, 'Добриво універсальне грунтове', 415)
# (5227876, 'Добриво універсальне грунтове', 950)
# (32237, 'Добриво для декоративних листових', 415)
# (4165215, 'Добриво для вічнозелених дерев та кущів', 1149)
# (682645, 'Добриво універсальне грунтове', 415)
# (7435, 'Добриво універсальне грунтове', 173)
# (9354141, 'Добриво для газону', 415)
# (1955, 'Добриво для вічнозелених дерев та кущів', 173)
# (455799, 'Добриво для газону', 173)
# (991645, 'Добриво для декоративних листових', 173)
# (17477, 'Добриво універсальне грунтове', 1149)
# (7143174, 'Добриво для газону', 350)
# (3593, 'Добриво для полуниці', 155)
# (4738184, 'Добриво для вічнозелених дерев та кущів', 350)
# (3177412, 'Добриво для фруктових та горіхових дерев', 173)
# (16762, 'Добриво для газону', 1149)
# (78747, 'Добриво для декоративних листових', 375)
# (5218, 'Добриво для вічнозелених дерев та кущів', 999)
# (33486, 'Добриво для декоративних листових', 155)
# (198742, 'Добриво для овочів', 350)
# (797756, 'Добриво для винограду', 155)
# (726319, 'Добриво для вічнозелених дерев та кущів', 415)
# (789868, 'Добриво для газону', 155)
# (88255, 'Добриво для овочів', 155)
# (68183, 'Добриво для розсади', 173)
# (5656841, 'Добриво для тепличних овочів', 415)
# (2217672, 'Добриво для троянд', 155)
# (8362626, 'Добриво для вічнозелених дерев та кущів', 155)
# (375738, 'Добриво для газону', 999)
# (51561, 'Добриво для тепличних овочів', 125)

# %% [markdown]
# ### Завдання 3:

# %% [markdown]
# Ознайомтеся із роботою SQLite та відповідним модулем у Python.
# Завантажте базу даних для виконання лабораторної роботи.
# Підключіться до завантаженої бази SQLite.

# %% [markdown]
# 1. Виведіть інформацію про дану базу.

# %% [markdown]
# 2. Виведіть перелік всіх таблиць.

# %% [markdown]
# 3. Список всіх cust_id з таблиці Customers table.

# %% [markdown]
# 4. Всю таблицю Customers table

# %% [markdown]
# 5. Список клієнтів (cust_names) відсортованих від Z до A

# %% [markdown]
# 6. Таблицю клієнтів та замовлень (cust_id і order_num) . Відсортуйте по клієнту і потім по даті замовлення

# %% [markdown]
# 7. Таблицю (на основі Items) з кількість та вартістю товару. Відсортуйте в порядку спадання по кількості та вартості

# %% [markdown]
# 8. Товар (з таблиці Products), ціна якого становить 9.49

# %% [markdown]
# 9. Виведіть назву товару та ціну, яка лежить в діапазоні від  3 до 6. Відсортуйте результат в по ціні в порядку зростання

# %% [markdown]
# 10. Кількість товару, що було продано

# %% [markdown]
# 11. Кількість найменувань товару, ціна якого більша за 4

# %% [markdown]
# 12. Розробіть алгоритм для виведення 3 найдорожчих товарів в базі

# %% [markdown]
# 13. Підрахуйте кількість замовлень для кожного клієнта використовуючи підзапити

# %% [markdown]
# 14. Виведіть список клієнтів та їх замовлення (використайте JOIN)

# %% [markdown]
# 15. Зробіть два запити: список товарів, ціна яких менша 5 та список товарів, ціна який більша рівна 5. Використайте UNION для об'єднання цих запитів

# %% [markdown]
# ### Завдання 4:

# %% [markdown]
# Зареєструйтеся на сайті  http://www.sql-ex.ru/
#
# Виконайте завдання із блоку SELECT; з 1 по 30 завдання
#
# Код запитів вставляйте сюди
